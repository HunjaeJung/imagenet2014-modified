# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
import numpy as np

# plt.rcParams['figure.figsize'] = (10, 10)
# plt.rcParams['image.interpolation'] = 'nearest'
# plt.rcParams['image.cmap'] = 'gray'

# %%
DIR_PATH = '/shared/flickr_style/'
TRAIN_TXT = 'train.txt'
TEST_TXT = 'test.txt'
CLASS_NAME_TXT = 'style_names.txt'
TEST_RESULT = './label_result.csv'
style_names = np.loadtxt(DIR_PATH + CLASS_NAME_TXT, str, delimiter='\t')

# %%
df_test = pd.read_csv(DIR_PATH + TEST_TXT, delimiter=' ', header=None)
df_test.columns = ['url', 'class']
df_test.tail()
# Out:
#                                                      url  class
# 15981  /home/hawk/caffe/data/flickr_style/images/8707...      1
# 15982  /home/hawk/caffe/data/flickr_style/images/1312...      4
# 15983  /home/hawk/caffe/data/flickr_style/images/1236...      9
# 15984  /home/hawk/caffe/data/flickr_style/images/6219...      5
# 15985  /home/hawk/caffe/data/flickr_style/images/9913...     10

# %%
df_test['class'].value_counts()
# Out:
# 15    800
# 19    800
# 16    800
# 1     800
# 9     800
# 17    800
# 18    800
# 7     800
# 3     800
# 4     800
# 14    800
# 12    799
# 2     799
# 13    799
# 6     799
# 0     799
# 11    798
# 10    798
# 8     798
# 5     797
# dtype: int64

# %%
df_train = pd.read_csv(DIR_PATH + TRAIN_TXT, delimiter=' ', header=None)
df_train.columns = ['url', 'class']
df_train['class'].value_counts()
# Out:
# 9     3200
# 17    3200
# 16    3200
# 3     3200
# 14    3200
# 8     3200
# 7     3199
# 13    3199
# 12    3199
# 4     3199
# 18    3199
# 5     3198
# 19    3198
# 0     3198
# 11    3197
# 2     3197
# 10    3196
# 1     3196
# 15    3195
# 6     3194
# dtype: int64

# %%
def plot_confusion_matrix(cm, target_names, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(target_names))
    plt.xticks(tick_marks, target_names, rotation=45)
    plt.yticks(tick_marks, target_names)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
df_result = pd.read_csv(TEST_RESULT, header=None)
df_result.columns = ['url', 'true', 'sfmax', 'svm']
df_result.tail()
# Out:
#                                                      url  true  sfmax  svm
# 13867  /home/hawk/caffe/data/flickr_style/images/8707...     1     13    3
# 13868  /home/hawk/caffe/data/flickr_style/images/1312...     4      5    6
# 13869  /home/hawk/caffe/data/flickr_style/images/1236...     9      0    8
# 13870  /home/hawk/caffe/data/flickr_style/images/6219...     5      5    5
# 13871  /home/hawk/caffe/data/flickr_style/images/9913...    10     10   10

# %%
target_names = style_names
y_true = df_result.true.values
y_pred_svm = df_result.svm.values
y_pred_sfmax = df_result.sfmax.values
df = pd.DataFrame(columns=['name', 'precision_svm', 'precision_sfmax'])
df.name = style_names
df.precision_svm = precision_score(y_true, y_pred_svm, average=None)
df.precision_sfmax = precision_score(y_true, y_pred_sfmax, average=None)

# %%
df
# Out:
#                      name  precision_svm  precision_sfmax
# 0                Detailed       0.530435         0.380789
# 1                  Pastel       0.508257         0.337413
# 2              Melancholy       0.424290         0.220430
# 3                    Noir       0.570694         0.457998
# 4                     HDR       0.589587         0.517296
# 5                 Vintage       0.480916         0.160510
# 6           Long Exposure       0.294300         0.529960
# 7                  Horror       0.578797         0.438547
# 8                   Sunny       0.638889         0.507335
# 9                  Bright       0.467818         0.290262
# 10                   Hazy       0.639818         0.545858
# 11                  Bokeh       0.514516         0.307815
# 12                 Serene       0.485628         0.369025
# 13                Texture       0.516484         0.320359
# 14               Ethereal       0.590244         0.442897
# 15                  Macro       0.626973         0.557103
# 16         Depth of Field       0.443939         0.240385
# 17  Geometric Composition       0.547049         0.404568
# 18                Minimal       0.588502         0.460414
# 19               Romantic       0.474124         0.309524

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (20, 10)
ax = df.plot(kind='bar')
ax.xaxis.set_ticklabels(style_names)
# Out:
# [<matplotlib.text.Text at 0x7f1e0f784d90>,
#  <matplotlib.text.Text at 0x7f1e0f78da90>,
#  <matplotlib.text.Text at 0x7f1e0f62c190>,
#  <matplotlib.text.Text at 0x7f1e0f62c910>,
#  <matplotlib.text.Text at 0x7f1e0f6350d0>,
#  <matplotlib.text.Text at 0x7f1e0f635850>,
#  <matplotlib.text.Text at 0x7f1e0f635fd0>,
#  <matplotlib.text.Text at 0x7f1e0f641790>,
#  <matplotlib.text.Text at 0x7f1e0f641f10>,
#  <matplotlib.text.Text at 0x7f1e0f64a6d0>,
#  <matplotlib.text.Text at 0x7f1e0f64ae50>,
#  <matplotlib.text.Text at 0x7f1e0f654610>,
#  <matplotlib.text.Text at 0x7f1e0f654d90>,
#  <matplotlib.text.Text at 0x7f1e0f5de550>,
#  <matplotlib.text.Text at 0x7f1e0f5decd0>,
#  <matplotlib.text.Text at 0x7f1e0f5e8490>,
#  <matplotlib.text.Text at 0x7f1e0f5e8c10>,
#  <matplotlib.text.Text at 0x7f1e0f5f03d0>,
#  <matplotlib.text.Text at 0x7f1e0f5f0b50>,
#  <matplotlib.text.Text at 0x7f1e0f5fc310>]

# %%
print precision_score(y_true, y_pred_svm, average=None)
print precision_score(y_true, y_pred_svm, average='weighted')
# Out:
# [ 0.53  0.51  0.42  0.57  0.59  0.48  0.29  0.58  0.64  0.47  0.64  0.51
#   0.49  0.52  0.59  0.63  0.44  0.55  0.59  0.47]
# 0.525852469149

# %%
print precision_score(y_true, y_pred_sfmax, average=None)
print precision_score(y_true, y_pred_sfmax, average='weighted')
# Out:
# [ 0.38  0.34  0.22  0.46  0.52  0.16  0.53  0.44  0.51  0.29  0.55  0.31
#   0.37  0.32  0.44  0.56  0.24  0.4   0.46  0.31]
# 0.390109975576

# %%
cm_sfmax = confusion_matrix(y_test, y_pred_sfmax)
cm_normalized = cm_sfmax.astype('float') / cm.sum(axis=1)[:, np.newaxis]
np.set_printoptions(precision=2)
plt.figure(figsize=(15, 15))
plot_confusion_matrix(cm_normalized, target_names, title='Normalized confusion matrix of karayev')
plt.show()

# %%
cm_svm = confusion_matrix(y_test, y_pred_svm)
cm_normalized = cm_sfmax.astype('float') / cm.sum(axis=1)[:, np.newaxis]
np.set_printoptions(precision=2)
plt.figure(figsize=(15, 15))
plot_confusion_matrix(cm_normalized, target_names, title='Normalized confusion matrix of our method')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6312bad29ff7> in <module>()
# ----> 1 cm_svm = confusion_matrix(y_test, y_pred_svm)
#       2 cm_normalized = cm_sfmax.astype('float') / cm.sum(axis=1)[:, np.newaxis]
#       3 np.set_printoptions(precision=2)
#       4 plt.figure(figsize=(15, 15))
#       5 plot_confusion_matrix(cm_normalized, target_names, title='Normalized confusion matrix of our method')
#
# NameError: name 'confusion_matrix' is not defined

# %%
from sklearn.manifold import TSNE

model = TSNE(n_components=2, random_state=0)

# %%
import pickle

# %%
vec = pickle.load(open('feat_train.pickle', 'rb'))
model.fit_transform(vec)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-6-baf361fbe37e> in <module>()
#       1 vec = pickle.load(open('feat_train.pickle', 'rb'))
# ----> 2 model.fit_transform(vec)
#
# /home/hawk/.virtualenvs/py2/local/lib/python2.7/site-packages/sklearn/manifold/t_sne.pyc in fit_transform(self, X, y)
#     522             Embedding of the training data in low-dimensional space.
#     523         """
# --> 524         self.fit(X)
#     525         return self.embedding_
#
# /home/hawk/.virtualenvs/py2/local/lib/python2.7/site-packages/sklearn/manifold/t_sne.pyc in fit(self, X, y)
#     436
#     437             if self.metric == "euclidean":
# --> 438                 distances = pairwise_distances(X, metric=self.metric, squared=True)
#     439             else:
#     440                 distances = pairwise_distances(X, metric=self.metric)
#
# /home/hawk/.virtualenvs/py2/local/lib/python2.7/site-packages/sklearn/metrics/pairwise.pyc in pairwise_distances(X, Y, metric, n_jobs, **kwds)
#    1108         func = partial(distance.cdist, metric=metric, **kwds)
#    1109
# -> 1110     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1111
#    1112
#
# /home/hawk/.virtualenvs/py2/local/lib/python2.7/site-packages/sklearn/metrics/pairwise.pyc in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#     958     if n_jobs == 1:
#     959         # Special case to avoid picklability checks in delayed
# --> 960         return func(X, Y, **kwds)
#     961
#     962     # TODO: in some cases, backend='threading' may be appropriate
#
# /home/hawk/.virtualenvs/py2/local/lib/python2.7/site-packages/sklearn/metrics/pairwise.pyc in euclidean_distances(X, Y, Y_norm_squared, squared)
#     205         XX = row_norms(X, squared=True)[:, np.newaxis]
#     206
# --> 207     distances = safe_sparse_dot(X, Y.T, dense_output=True)
#     208     distances *= -2
#     209     distances += XX
#
# /home/hawk/.virtualenvs/py2/local/lib/python2.7/site-packages/sklearn/utils/extmath.pyc in safe_sparse_dot(a, b, dense_output)
#     181         return ret
#     182     else:
# --> 183         return fast_dot(a, b)
#     184
#     185
#
# MemoryError:
